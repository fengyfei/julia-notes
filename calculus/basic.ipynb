# %%
using Gadfly
set_default_plot_size(16cm, 16cm)

# %%
using Calculus

# %%
plot([sin, derivative(sin)], 0, 4pi)
# Out:
# Plot(...)

# %%
plot([cos, derivative(cos)], 0, 4pi)
# Out:
# Plot(...)

# %%
plot([expm1, derivative(expm1)], 0, 2)
# Out:
# Plot(...)

# %%
plot([exp, derivative(exp)], 0, 2)
# Out:
# Plot(...)

# %%
plot([exp2, derivative(exp2)], 0, 2)
# Out:
# Plot(...)

# %%
plot([exp10, derivative(exp10)], 0, 2)
# Out:
# Plot(...)

# %%
plot([log10, derivative(log10)], 1, 10)
# Out:
# Plot(...)

# %%
plot([log2, derivative(log2)], 1, 10)
# Out:
# Plot(...)

# %%
plot([log, derivative(log)], 1, 10)
# Out:
# Plot(...)
