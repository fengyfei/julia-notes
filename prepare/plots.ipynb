# %%
using Pkg
# uncomment the flowing if ffmpeg not found
# Pkg.rm("Plots")
# Pkg.rm("PyPlot")
# Pkg.gc()
Pkg.add("Plots")
Pkg.add("PyPlot")
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#   [91a5bcdd] + Plots v0.26.2
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#   [c87230d0] + FFMPEG v0.2.2
#   [28b8d3ca] + GR v0.41.0
#   [4d00f742] + GeometryTypes v0.7.6
#   [ccf2f8ad] + PlotThemes v0.3.0
#   [995b91a9] + PlotUtils v0.5.8
#   [91a5bcdd] + Plots v0.26.2
#   [3cdcf5f2] + RecipesBase v0.7.0
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#   [d330b81b] + PyPlot v2.8.2
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#   [438e738f] + PyCall v1.91.2
#   [d330b81b] + PyPlot v2.8.2

# %%
using Plots
pyplot()

n = 100
ts = range(0, stop=8π, length=n)
x = ts .* map(cos, ts)
y = (0.1ts) .* map(sin, ts)
z = 1:n
plot(x, y, z, zcolor=reverse(z), m=(10, 0.8, :blues, Plots.stroke(0)), leg=false, cbar=true, w=5)
plot!(zeros(n), zeros(n), 1:n, w=10)
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/fengyfei/.julia/conda/3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cycler-0.10.0              |           py37_0          14 KB
#     freetype-2.9.1             |       hb4e5f40_0         555 KB
#     kiwisolver-1.1.0           |   py37h0a44026_0          54 KB
#     matplotlib-3.1.1           |   py37h54f8f79_0         6.6 MB
#     pyparsing-2.4.2            |             py_0          61 KB
#     pytz-2019.2                |             py_0         245 KB
#     ------------------------------------------------------------
#                                            Total:         7.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             pkgs/main/osx-64::cycler-0.10.0-py37_0
# ...
