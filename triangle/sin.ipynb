# %%
using Gadfly
set_default_plot_size(16cm, 16cm)

# %%
plot([sin, (x) -> limit(sin(x + h), h, 0)], -4pi, 4pi)
# Out:
# Plot(...)

# %%
plot(sin, pi/32, pi/16)
# Out:
# Plot(...)

# %%
plot(sin, pi/16, pi/8)
# Out:
# Plot(...)

# %%
plot(sin, pi/8, pi/4)
# Out:
# Plot(...)

# %%
plot(sin, pi/4, pi/2)
# Out:
# Plot(...)

# %%
plot(sin, pi/2, (3/4)pi)
# Out:
# Plot(...)

# %%
plot(sin, (3/4)pi, pi)
# Out:
# Plot(...)

# %%
plot([sin, (x) -> x - (x^3)/(1 * 2 *3)], -pi, pi)
# Out:
# Plot(...)

# %%
plot([sin, (x) -> x - (x^3)/(1 * 2 *3) + (x^5)/(1 * 2 * 3 * 4 * 5)], -pi, pi)
# Out:
# Plot(...)

# %%
plot([sin, (x) -> x - (x^3)/(1 * 2 *3) + (x^5)/(1 * 2 * 3 * 4 * 5) - (x^7)/(1 * 2 * 3 * 4 * 5 * 6 * 7)], -pi, pi)
# Out:
# Plot(...)

# %%
plot([sin, (x) -> x - (x^3)/(1 * 2 *3) + (x^5)/(1 * 2 * 3 * 4 * 5) - (x^7)/(1 * 2 * 3 * 4 * 5 * 6 * 7) + (x^9)/(1 * 2 * 3 * 4 * 5 * 6 * 7 * 8 * 9)], -pi, pi)
# Out:
# Plot(...)
